# %% [markdown]
# # Data science Tools and Ecosystem

# %% [markdown]
#  In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
#  Some of the popular languages that Data Scientist use are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# Some of the commonly used librariesused by Data scientist include:
#
# 1. NumPy
# 2. Pandas
# 3. Matplottlib

# %% [markdown]
# | Data science Tools |
# |--------------------|
# | JupyterLab |
# | RStudio  |
# | VS Code  |

# %% [markdown]
# ### Below are few eexamples of eventuating arithmetic expressions in Python.

# %%
# this is a simple arithmethic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60

200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# **Objetives:**
#
# - List popular languages for Data Science
# - List commonly used libraries for Data Science
# - List data tools
# - Demonstrate arithmetic expressions in Python
# - Convert minutes to hours in Python

# %% [markdown]
# ## Author
#
# jazmin carioli
